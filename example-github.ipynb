# %% [markdown]
# # Example for hosting a Jupyter Notebook as a HTML file

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("tips.csv")

# %%
sns.relplot(df)

# %%
sns.catplot(df)
